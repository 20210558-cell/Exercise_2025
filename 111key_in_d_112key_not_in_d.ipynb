# %% [markdown]
# <a href="https://colab.research.google.com/github/20210558-cell/Homework_2025/blob/main/111key_in_d_112key_not_in_d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
names = {'Mary':10999, 'Cris':2111, 'Aimy':9778, 'Tom':20245}
name = input('이름을 입력하세요: ')
if name in names:
  print(f'이름이 <{name}>인 출생아수는 <{names[name]:,d}>명입니다.')
else:
  print(f'딕셔너리 names에 <{name}>인 이름이 존재하지 않습니다.')
# Out:
# 이름을 입력하세요: Cris
# 이름이 <Cris>인 출생아수는 <2,111>명입니다.

# %%
frequency = { }
while True:
  c = input('알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]:')
  if c == '':
    break
  if c not in frequency:
    frequency[c] = 1
  else:
    frequency[c] += 1
  print(frequency)
# Out:
# 알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]:a
# {'a': 1}
# 알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]:b
# {'a': 1, 'b': 1}
# 알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]:c
# {'a': 1, 'b': 1, 'c': 1}
# 알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]:a
# {'a': 2, 'b': 1, 'c': 1}
# 알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]:c
# {'a': 2, 'b': 1, 'c': 2}
# 알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]:
