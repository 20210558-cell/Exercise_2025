# %% [markdown]
# <a href="https://colab.research.google.com/github/20210558-cell/Homework_2025/blob/main/158os_path_getsize_159os_remove.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os.path import getsize

file1 = 'sunrise.jpg'                   # 파일 이름만
file2 = 'C:/data/temp/DJI_0128.MP4'     # 절대경로
file3 = '../../temp/DJI_0129.MP4'       # 상대경로

# %%
print(f'{file1}: {getsize(file1):,} 바이트')
print(f'{file2}: {getsize(file2):,} 바이트')
print(f'{file3}: {getsize(file3):,} 바이트')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-49541015.py in <cell line: 0>()
# ----> 1 print(f'{file1}: {getsize(file1):,} 바이트')
#       2 print(f'{file2}: {getsize(file2):,} 바이트')
#       3 print(f'{file3}: {getsize(file3):,} 바이트')
#
# /usr/lib/python3.12/genericpath.py in getsize(filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sunrise.jpg'

# %%
from os import remove

target = 'mydata.txt'
k = input(f'<target>을 삭제하시겠습니까? (y/n)')
if k.lower() == 'y':
  remove(target)
  print(f'<{target}>을 삭제했습니다.')
else:
  print(f'<{target}>을 삭제하지 않았습니다.')
# Out:
# <target>을 삭제하시겠습니까? (y/n)y
# <mydata.txt>을 삭제했습니다.
