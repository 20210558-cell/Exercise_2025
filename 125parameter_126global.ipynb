# %% [markdown]
# <a href="https://colab.research.google.com/github/20210558-cell/Homework_2025/blob/main/125parameter_126global.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def setLevel(character, level=1):
  print(f'{character}의 레벨: {level}')
  return

# %%
setLevel('유비')
setLevel('제갈량', 10)
# Out:
# 유비의 레벨: 1
# 제갈량의 레벨: 10

# %%
def setLevel(level=1, character):
  ...
# Out:
#   File "/tmp/ipython-input-645197274.py", line 1
#     def setLevel(level=1, character):
#                           ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
def setLevel(character, level=1):
  print(f'{character}의 레벨: {level}')
  return

# %%
setLevel(level=5, character='장비')
# Out:
# 장비의 레벨: 5

# %%
def setLevel(*args):
  print(args)
  return

# %%
setLevel('관우', 7)
setLevel('조운', 'named', 10)
# Out:
# ('관우', 7)
# ('조운', 'named', 10)

# %%
def setLevel(**kwargs):
  print(kwargs)
  return

# %%
setLevel(character='조운', level=10)
setLevel(character='황충', category='named', level=5)
# Out:
# {'character': '조운', 'level': 10}
# {'character': '황충', 'category': 'named', 'level': 5}

# %%
def setLevel(character, level, *args):
  print(f'장수:{character}, 레벨:{level}')
  if len(args) != 0:
    print(f'기타 특성: {args}')
  return

# %%
setLevel('조조', 3)
# Out:
# 장수:조조, 레벨:3

# %%
setLevel('유비', 3, 'named', 'leader')
# Out:
# 장수:유비, 레벨:3
# 기타 특성: ('named', 'leader')

# %%
def setLevel(character, level, **kwargs):
  print(f'장수:{character}, 레벨:{level}')
  if len(kwargs) != 0:
    for k, v in kwargs.items():
      print(f'{k}: {v}')
  return

# %%
setLevel('조조', 3)
# Out:
# 장수:조조, 레벨:3

# %%
setLevel('유비', 3, category='named', position='leader')
# Out:
# 장수:유비, 레벨:3
# category: named
# position: leader

# %%
param = 10
def func1(param):
  localData = 5
  print(f'param={param}')
  return

func1(5)
print(f'param={param}')
# Out:
# param=5
# param=10

# %%
param = 10
def func2():
  param = 20
  return param

ret = func2()   # ret의 값은 20입니다.
print(f'param={param}')
# Out:
# param=10

# %%
param = 10
def func3():
  global param    # 전역변수 param임을 명시함
  param = 20
  return

func3()
print(f'param={param}')
# Out:
# param=20
