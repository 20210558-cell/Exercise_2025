# %% [markdown]
# <a href="https://colab.research.google.com/github/20210558-cell/Homework_2025/blob/main/173regular_Expression_regex_174regular_Expression_re.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
p = re.compile(r'href=".*?"', re.I)

# %%
contents = """<a href="help.html">의 도움말을 보려면 여기를 클릭하세요</a><font size="15">"""
ret = p.match(contents)
print(ret)
# Out:
# None

# %%
contents2 = """href="help.html">도움말을 보려면 여기를 클릭하세요</a><font size="15">"""
ret = p.match(contents2)
print(ret.group())
# Out:
# href="help.html">도움말을 보려면 여기를 클릭하세요</a><font size="15"

# %%
ret = p.search(contents)
print(f'Match.group( )={ret.group( )}')
print(f'Match.start( )={ret.start( )}')
print(f'Match.end( )={ret.end( )}')
print(f'Match.span( )={ret.span( )}')
# Out:
# Match.group( )=href="help.html">의 도움말을 보려면 여기를 클릭하세요</a><font size="15"
# Match.start( )=3
# Match.end( )=59
# Match.span( )=(3, 59)

# %%
ret = p.findall(contents)
print(ret)
# Out:
# ['href="help.html">의 도움말을 보려면 여기를 클릭하세요</a><font size="15"']

# %%
p = re.compile(r'src=\S+"', re.I)
with open('webpage.html') as f:
  contents = f.read()

imgurls = p.findall(contents)
for imgurl in imgurls:
  imgurl = imgurl.split('"')[1]
  print(imgurl)
# Out:
# /static/images/2024-08-25_234806.jpg
# /static/images/2024-08-25_234836.jpg
# /static/images/2024-08-25_234910.jpg
