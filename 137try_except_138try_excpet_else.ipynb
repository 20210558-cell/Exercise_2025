# %% [markdown]
# <a href="https://colab.research.google.com/github/20210558-cell/Homework_2025/blob/main/137try_except_138try_excpet_else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fileList = ['file01.jpg', 'file02.jpg', 'file03', 'file04.jpg']
for file in fileList:
  fname = file.split('.')
  print(f'파일 이름: {file[0]}, 파일확장자: {fname[1]}')
# Out:
# 파일 이름: f, 파일확장자: jpg
# 파일 이름: f, 파일확장자: jpg
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-2903264407.py in <cell line: 0>()
#       2 for file in fileList:
#       3   fname = file.split('.')
# ----> 4   print(f'파일 이름: {file[0]}, 파일확장자: {fname[1]}')
#
# IndexError: list index out of range

# %%
for file in fileList:
  try:
    fname = file.split('.')         # 파일 이름과 파일확장자 분리
    print(f'파일 이름: {fname[0]}, 파일확장자: {fname[1]}')
  except:
    print(f'ERROR!! <{file}> 처리중 예외 발생!')
# Out:
# 파일 이름: file01, 파일확장자: jpg
# 파일 이름: file02, 파일확장자: jpg
# ERROR!! <file03> 처리중 예외 발생!
# 파일 이름: file04, 파일확장자: jpg

# %%
fileList = ['file01.jpg', 'file02.jpg', 'file03', 'file04.jpg']
try:
  for file in fileList:
    fname = file.split('.')         # 파일 이름과 파일확장자 분리
    print(f'파일 이름: {fname[0]}, 파일확장자: {fname[1]}')
except:
  print(f'ERROR!! <{file}> 처리중 오류 발생!')
else:
  print('모든 파일을 성공적으로 처리했습니다.')
# Out:
# 파일 이름: file01, 파일확장자: jpg
# 파일 이름: file02, 파일확장자: jpg
# ERROR!! <file03> 처리중 오류 발생!

# %%
fileList = ['file01.jpg', 'file02.jpg', 'file03.jpg', 'file04.jpg']
try:
  for file in fileList:
    fname = file.split('.')         # 파일 이름과 파일확장자 분리
    print(f'파일 이름: {fname[0]}, 파일확장자: {fname[1]}')
except:
  print(f'ERROR!! <{file}> 처리중 오류 발생!')
else:
  print('모든 파일을 성공적으로 처리했습니다.')
# Out:
# 파일 이름: file01, 파일확장자: jpg
# 파일 이름: file02, 파일확장자: jpg
# 파일 이름: file03, 파일확장자: jpg
# 파일 이름: file04, 파일확장자: jpg
# 모든 파일을 성공적으로 처리했습니다.
