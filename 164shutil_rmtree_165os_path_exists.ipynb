# %% [markdown]
# <a href="https://colab.research.google.com/github/20210558-cell/Homework_2025/blob/main/164shutil_rmtree_165os_path_exists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from shutil import rmtree

folder = '/content/myfolder'
k = input(f'<{folder}>를 완전히 삭제하시겠습니까? (y/n): ')
if k.lower() == 'y':
  rmtree(folder)
  print(f'<{folder}>를 완전히 삭제했습니다.')
else:
  print(f'<{folder}>를 삭제하지 않습니다.')
# Out:
# </content/myfolder>를 완전히 삭제하시겠습니까? (y/n): y
# </content/myfolder>를 완전히 삭제했습니다.

# %%
from os.path import exists

print(exists('sunrise.jpg'))
print(exists('tmp'))
print(exists('/content/bts.mp4'))
# Out:
# True
# True
# False

# %%
from os import mkdir
from os.path import exists

while True:
  folder = input('생성할 디렉토리 이름을 입력하세요: ')
  if exists(folder):
    print(f'<{folder}>가 이미 존재합니다.')
    continue
  else:
    mkdir(folder)
    print(f'<{folder}>를 생성했습니다.')
    break
# Out:
# 생성할 디렉토리 이름을 입력하세요: tmp
# <tmp>가 이미 존재합니다.
# 생성할 디렉토리 이름을 입력하세요: tmp2
# <tmp2>를 생성했습니다.
