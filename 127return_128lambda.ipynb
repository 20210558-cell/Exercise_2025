# %% [markdown]
# <a href="https://colab.research.google.com/github/20210558-cell/Homework_2025/blob/main/127return_128lambda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def reverse(*args):
  result = [ ]
  idx = len(args)-1
  while idx >= 0:
    result.append(args[idx])
    idx -= 1
  return result

# %%
ret = reverse('가', '나', '다', '라')
print(ret)
# Out:
# ['라', '다', '나', '가']

# %%
f = lambda x: x**2
print(f(2))
print(f(3))
# Out:
# 4
# 9

# %%
f = lambda x: x+'.txt'
print(f('readme'))
# Out:
# readme.txt

# %%
f = lambda x: x[1]
print(f('readme'))
print(f(('장비', 10)))
# Out:
# e
# 10
