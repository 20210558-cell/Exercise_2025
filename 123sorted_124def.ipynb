# %% [markdown]
# <a href="https://colab.research.google.com/github/20210558-cell/Homework_2025/blob/main/123sorted_124def.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
greats = {'유비':89, '관우':95, '장비':91, '조운':94}
ret = sorted(greats)
print(ret)
# Out:
# ['관우', '유비', '장비', '조운']

# %%
ret = sorted(greats.items())
print(ret)
# Out:
# [('관우', 95), ('유비', 89), ('장비', 91), ('조운', 94)]

# %%
ret = sorted(greats.items(), reverse=True)
print(ret)
# Out:
# [('조운', 94), ('장비', 91), ('유비', 89), ('관우', 95)]

# %%
ret = sorted(greats.items(), key=lambda x: x[1])
print(ret)
# Out:
# [('유비', 89), ('장비', 91), ('조운', 94), ('관우', 95)]

# %%
ret = sorted(greats.items(), key=lambda x: x[1], reverse=True)
print(ret)
# Out:
# [('관우', 95), ('조운', 94), ('장비', 91), ('유비', 89)]

# %%
for name, level in ret:
  print(f'<{name}>의 레벨은 <{level}>입니다.')
# Out:
# <관우>의 레벨은 <95>입니다.
# <조운>의 레벨은 <94>입니다.
# <장비>의 레벨은 <91>입니다.
# <유비>의 레벨은 <89>입니다.

# %%
def displayFilepath():
  filepath = 'c:/myworks/pythonstrudy.py'
  print(f'파일경로: {filepath}')
  return

displayFilepath()
# Out:
# 파일경로: c:/myworks/pythonstrudy.py

# %%
def printFilepath(folder, filename):
  print(f'파일경로: {folder+filename}')
  return

printFilepath('c:/mywork/', 'pythonstudy.py')
# Out:
# 파일경로: c:/mywork/pythonstudy.py

# %%
def getFilepath():
  filepath = 'c:/myworks/pythonstudy.py'
  return filepath

filepath = getFilepath()
print(f'파일경로: {filepath}')
# Out:
# 파일경로: c:/myworks/pythonstudy.py

# %%
def makeFilepath(folder, filename):
  return folder + filename

filepath = makeFilepath('c:/mywork/', 'pythonstudy.py')
print(f'파일경로: {filepath}')
# Out:
# 파일경로: c:/mywork/pythonstudy.py
