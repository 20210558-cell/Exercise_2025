# %% [markdown]
# <a href="https://colab.research.google.com/github/20210558-cell/Homework_2025/blob/main/115d_copy_116d_items.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
greats = {'유비':89, '관우':95, '장비':91, '조운':94}
buffer = greats.copy()
del buffer['관우']
print(f'greats: {greats}')
print(f'buffer: {buffer}')
# Out:
# greats: {'유비': 89, '관우': 95, '장비': 91, '조운': 94}
# buffer: {'유비': 89, '장비': 91, '조운': 94}

# %%
greats = {'유비':89, '관우':95, '장비':91, '조운':94}
generals = greats.items()
print(list(generals))
# Out:
# [('유비', 89), ('관우', 95), ('장비', 91), ('조운', 94)]

# %%
greats = {'유비':89, '관우':95, '장비':91, '조운':94}
del greats['관우']
print(list(generals))
# Out:
# [('유비', 89), ('장비', 91), ('조운', 94)]
