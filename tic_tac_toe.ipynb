# %% [markdown]
# <a href="https://colab.research.google.com/github/20210558-cell/Homework_2025/blob/main/tic_tac_toe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
board = [' ' for _ in range(9)]

def display_board():
    print("\n")
    print(f" {board[0]} | {board[1]} | {board[2]} ")
    print("---+---+---")
    print(f" {board[3]} | {board[4]} | {board[5]} ")
    print("---+---+---")
    print(f" {board[6]} | {board[7]} | {board[8]} ")
    print("\n")

def check_win(mark):
    if board[0] == board[1] == board[2] == mark: return True
    if board[3] == board[4] == board[5] == mark: return True
    if board[6] == board[7] == board[8] == mark: return True
    if board[0] == board[3] == board[6] == mark: return True
    if board[1] == board[4] == board[7] == mark: return True
    if board[2] == board[5] == board[8] == mark: return True
    if board[0] == board[4] == board[8] == mark: return True
    if board[2] == board[4] == board[6] == mark: return True

    return False

def is_board_full():
    return ' ' not in board

print("=== 틱택토 게임 ===")
print(" 1 | 2 | 3 ")
print("---+---+---")
print(" 4 | 5 | 6 ")
print("---+---+---")
print(" 7 | 8 | 9 ")

current_player = 'X'

while True:
    display_board()

    choice = input(f"[{current_player}]의 차례입니다. 위치(1~9)를 입력하세요 : ")

    if not choice.isdigit():
        print("숫자를 입력해주세요.")
        continue

    choice = int(choice)

    if choice < 1 or choice > 9:
        print("1부터 9 사이의 숫자를 입력해주세요.")
        continue

    index = choice - 1
    if board[index] != ' ':
        print("이미 놓여진 자리입니다..")
        continue

    board[index] = current_player

    if check_win(current_player):
        display_board()
        print(f" [{current_player}] 승리!")
        break

    if is_board_full():
        display_board()
        print("무승부입니다.")
        break

    if current_player == 'X':
        current_player = 'O'
    else:
        current_player = 'X'
# Out:
# === 틱택토 게임 ===
#  1 | 2 | 3
# ---+---+---
#  4 | 5 | 6
# ---+---+---
#  7 | 8 | 9
#
#
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# [X]의 차례입니다. 위치(1~9)를 입력하세요 : 1
#
#
#  X |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# [O]의 차례입니다. 위치(1~9)를 입력하세요 : 5
#
#
#  X |   |
# ---+---+---
#    | O |
# ---+---+---
#    |   |
#
#
# [X]의 차례입니다. 위치(1~9)를 입력하세요 : 3
#
#
#  X |   | X
# ---+---+---
#    | O |
# ---+---+---
#    |   |
#
#
# [O]의 차례입니다. 위치(1~9)를 입력하세요 : 2
#
#
#  X | O | X
# ---+---+---
#    | O |
# ---+---+---
#    |   |
#
#
# [X]의 차례입니다. 위치(1~9)를 입력하세요 : 8
#
#
#  X | O | X
# ---+---+---
#    | O |
# ---+---+---
#    | X |
#
#
# [O]의 차례입니다. 위치(1~9)를 입력하세요 : 4
#
#
#  X | O | X
# ---+---+---
#  O | O |
# ---+---+---
#    | X |
#
#
# [X]의 차례입니다. 위치(1~9)를 입력하세요 : 6
#
#
#  X | O | X
# ---+---+---
#  O | O | X
# ---+---+---
#    | X |
#
#
# [O]의 차례입니다. 위치(1~9)를 입력하세요 : 9
#
#
#  X | O | X
# ---+---+---
#  O | O | X
# ---+---+---
#    | X | O
#
#
# [X]의 차례입니다. 위치(1~9)를 입력하세요 : 7
#
#
#  X | O | X
# ---+---+---
#  O | O | X
# ---+---+---
#  X | X | O
#
#
# 무승부입니다.
