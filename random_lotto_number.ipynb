# %% [markdown]
# <a href="https://colab.research.google.com/github/20210558-cell/Homework_2025/blob/main/random_lotto_number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import time

print("=== 로또 랜덤 번호 추천 ===")

for i in range(5):
    lotto = random.sample(range(1, 46), 6)
    lotto.sort()
    print(f"{i+1}번째 추천 번호: {lotto}")
# Out:
# === 로또 랜덤 번호 추천 ===
# 1번째 추천 번호: [11, 12, 16, 22, 39, 44]
# 2번째 추천 번호: [1, 4, 10, 26, 30, 35]
# 3번째 추천 번호: [5, 16, 23, 33, 43, 44]
# 4번째 추천 번호: [6, 7, 13, 29, 30, 41]
# 5번째 추천 번호: [10, 13, 21, 22, 33, 41]
