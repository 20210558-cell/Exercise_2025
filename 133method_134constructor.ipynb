# %% [markdown]
# <a href="https://colab.research.google.com/github/20210558-cell/Homework_2025/blob/main/133method_134constructor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Wizard:
  generated = 0

  # 인스턴스 메서드
  def setFireballLevel(self, power=1):
    self.fireballLevel = power
    print(f'화염구 강도를 {power}로 설정합니다.')

  # 클래스 메서드
  @classmethod
  def addGenerated(cls, count):
    cls.generated += count
    print(f'생성된 총 캐릭터 수: {cls.generated}')

  # 정적 메서드
  @staticmethod
  def static1():
    print('Wizard 클래스에서 정의된 정적 메서드입니다.')

# %%
player1 = Wizard()
player1.setFireballLevel(8)
Wizard.addGenerated(2)
Wizard.static1()
# Out:
# 화염구 강도를 8로 설정합니다.
# 생성된 총 캐릭터 수: 2
# Wizard 클래스에서 정의된 정적 메서드입니다.

# %%
class Wizard:
  def __init__(self):
    print('마법사 캐릭터가 생성되었습니다.')

# %%
player1 = Wizard()
# Out:
# 마법사 캐릭터가 생성되었습니다.

# %%
class Wizard:
  def __init__(self, name=None):
    self.name = name
    print(f'마법사 이름이 <{self.name}>인 캐릭터가 생성되었습니다.')

# %%
player1 = Wizard('StormBaby')
# Out:
# 마법사 이름이 <StormBaby>인 캐릭터가 생성되었습니다.
