# %% [markdown]
# <a href="https://colab.research.google.com/github/20210558-cell/Homework_2025/blob/main/113_iter_114d_clear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
greats = {'유비':89, '관우':95, '장비':91, '조운':94}
for name in iter(greats):
  print(name)
# Out:
# 유비
# 관우
# 장비
# 조운

# %%
greats = {'유비':89, '관우':95, '장비':91, '조운':94}
greats.clear()
print(greats)
# Out:
# {}

# %%
greats = {'유비':89, '관우':95, '장비':91, '조운':94}
del greatsprint(greats)
# Out:
#   File "/tmp/ipython-input-1582253117.py", line 2
#     del greatsprint(greats)
#         ^
# SyntaxError: cannot delete function call
